# %%
from pymongo import MongoClient

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from pprint import pprint

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\python.exe

# %%
# %pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Pandas Display Settings
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 120)

# Visualization Settings
plt.style.use("ggplot")
sns.set_theme(style="whitegrid")

plt.rcParams["figure.figsize"] = (10, 6)
plt.rcParams["figure.dpi"] = 120

# %%
client = MongoClient("mongodb://localhost:27017")

# %%
# !mongoimport --db sample_supplies --collection sales --file "D:\casestudy(DB)\sample_supplies\sales.json"
# Out:
# 2026-07-31T18:20:11.523+0530	connected to: mongodb://localhost/
# 2026-07-31T18:20:11.813+0530	continuing through error: E11000 duplicate key error collection: sample_supplies.sales index: _id_ dup key: { _id: ObjectId('5bd761dcae323e45a93ccfe8') }
# 2026-07-31T18:20:11.813+0530	continuing through error: E11000 duplicate key error collection: sample_supplies.sales index: _id_ dup key: { _id: ObjectId('5bd761dcae323e45a93ccfeb') }
# 2026-07-31T18:20:11.813+0530	continuing through error: E11000 duplicate key error collection: sample_supplies.sales index: _id_ dup key: { _id: ObjectId('5bd761dcae323e45a93ccfea') }
# 2026-07-31T18:20:11.813+0530	continuing through error: E11000 duplicate key error collection: sample_supplies.sales index: _id_ dup key: { _id: ObjectId('5bd761dcae323e45a93ccfec') }
# 2026-07-31T18:20:11.813+0530	continuing through error: E11000 duplicate key error collection: sample_supplies.sales index: _id_ dup key: { _id: ObjectId('5bd761dcae323e45a93ccfed') }
# ...

# %%
# !mongoimport --db sample_supplies --collection sales --file "D:\casestudy(DB)\sample_supplies\sales.json"
# Out:
# 2026-07-31T18:20:14.184+0530	connected to: mongodb://localhost/
# 2026-07-31T18:20:14.437+0530	continuing through error: E11000 duplicate key error collection: sample_supplies.sales index: _id_ dup key: { _id: ObjectId('5bd761dcae323e45a93ccfe8') }
# 2026-07-31T18:20:14.438+0530	continuing through error: E11000 duplicate key error collection: sample_supplies.sales index: _id_ dup key: { _id: ObjectId('5bd761dcae323e45a93ccfe9') }
# 2026-07-31T18:20:14.438+0530	continuing through error: E11000 duplicate key error collection: sample_supplies.sales index: _id_ dup key: { _id: ObjectId('5bd761dcae323e45a93ccfeb') }
# 2026-07-31T18:20:14.438+0530	continuing through error: E11000 duplicate key error collection: sample_supplies.sales index: _id_ dup key: { _id: ObjectId('5bd761dcae323e45a93ccfea') }
# 2026-07-31T18:20:14.438+0530	continuing through error: E11000 duplicate key error collection: sample_supplies.sales index: _id_ dup key: { _id: ObjectId('5bd761dcae323e45a93ccfed') }
# ...

# %%
db = client["sample_supplies"]

sales = db["sales"]

# %%
print(f"Database   : {db.name}")
print(f"Collection : {sales.name}")
print(f"Documents  : {sales.count_documents({}):,}")
# Out:
# Database   : sample_supplies
# Collection : sales
# Documents  : 5,000

# %%
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017")

print(client.list_database_names())
# Out:
# ['admin', 'config', 'local', 'sample_supplies']

# %%
db = client["sample_supplies"]
collection = db["sales"]

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('5bd761dcae323e45a93ccfeb'),
#  'saleDate': datetime.datetime(2015, 2, 23, 9, 53, 59, 343000),
#  'items': [{'name': 'binder',
#    'tags': ['school', 'general', 'organization'],
#    'price': Decimal128('20.08'),
#    'quantity': 1},
#   {'name': 'pens',
#    'tags': ['writing', 'office', 'school', 'stationary'],
#    'price': Decimal128('23.08'),
#    'quantity': 4},
#   {'name': 'backpack',
#    'tags': ['school', 'travel', 'kids'],
#    'price': Decimal128('82.73'),
#    'quantity': 2},
#   {'name': 'printer paper',
#    'tags': ['office', 'stationary'],
#    'price': Decimal128('15.98'),
#    'quantity': 3},
#   {'name': 'notepad',
#    'tags': ['office', 'writing', 'school'],
#    'price': Decimal128('27.24'),
#    'quantity': 4},
#   {'name': 'notepad',
#    'tags': ['office', 'writing', 'school'],
#    'price': Decimal128('27.7'),
#    'quantity': 5},
#   {'name': 'pens',
#    'tags': ['writing', 'office', 'school', 'stationary'],
# ...

# %%
print(f"total sales:{ collection.count_documents({}):,}")
# Out:
# total sales:5,000

# %%
plt.figure(figsize=(7, 6))

plt.bar(
    ["sales"],
    [collection.count_documents({})]
)

plt.title("total sales")
plt.ylabel("number of sales")

plt.show()
